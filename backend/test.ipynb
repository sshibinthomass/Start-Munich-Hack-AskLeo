# %%
import requests

API_BASE = "https://negbot-backend-ajdxh9axb0ddb0e9.westeurope-01.azurewebsites.net/api"
TEAM_ID = 851996  # Your team ID from the dashboard

# 1. List vendors
vendors_response = requests.get(
    f"{API_BASE}/vendors/",
    params={"team_id": TEAM_ID}
)
vendors = vendors_response.json()
vendor_id = vendors[0]["id"]

# 2. Create conversation
conversation_response = requests.post(
    f"{API_BASE}/conversations/",
    params={"team_id": TEAM_ID},
    json={
        "vendor_id": vendor_id,
        "title": "Price Negotiation"
    }
)
conversation = conversation_response.json()
conversation_id = conversation["id"]

# 3. Send message and get AI response (uses multipart/form-data for file support)

message_response = requests.post(
    f"{API_BASE}/messages/{conversation_id}",
    data={"content": "I need 100 units. What's your best price?"}
    # To attach files: files={"files": open("document.pdf", "rb")}
)
ai_response = message_response.json()
print(f"Vendor says: {ai_response['content']}")

# 4. Continue negotiation loop
while True:
    user_input = input("You: ")
    if user_input.lower() in ['quit', 'exit']:
        break

    response = requests.post(
        f"{API_BASE}/messages/{conversation_id}",
        data={"content": user_input}
    )
    ai_msg = response.json()
    print(f"Vendor: {ai_msg['content']}")
# Out:
# Vendor says: Ah, buongiorno! I appreciate your interest in acquiring 100 units; that is quite an impressive endeavor! But if I may be frank with you, the first step in our conversation should be to dive deeper into your project.
#
# What kind of space are you creating? What does coffee mean to your business? You see, the right machine is not just about quantity; it’s about quality, the experience you want to offer your guests, and how these machines will complement your aesthetic vision.
#
# Once I understand your vision, I would be delighted to discuss pricing with you, but I must emphasize that Victoria Arduino is not positioned to compete on price alone. Our machines are designed with an artistic flair and engineering excellence that one simply cannot find elsewhere.
#
# Please share more about your project, and then we can explore how to make this work together! Che bellezza, I am looking forward to it!
# Vendor: It seems there was a little hiccup; I didn’t receive your message. Please feel free to share your thoughts or details about your project when you’re ready! I am here to help you explore the perfect espresso solution for your vision. Let's create something beautiful together!
# Vendor: Ah, I see there was no text in your last message. No problem at all! Whenever you're ready, please share your thoughts or any details about your project. I am eager to assist you in finding the perfect espresso machines for your needs. Your vision is important to me, and I look forward to our conversation!
# Vendor: It appears that your message is still coming through empty. If you're experiencing any issues typing, please try refreshing the page or checking your connection.
#
# Whenever you're ready to share details about your project or ask any questions, I'm here to assist you with all things espresso! Just remember, the beauty of our machines goes hand in hand with the vision you have for your space. Let’s make something extraordinary happen together!

# %%
import requests

# Configuration
API_BASE = "https://negbot-backend-ajdxh9axb0ddb0e9.westeurope-01.azurewebsites.net/api"
TEAM_ID = 851996
VENDOR_ID = 44

print("🤝 Negotiation Bot - Vendor 44 Chat")
print("=" * 50)

# Create a new conversation
print(f"\n📝 Creating conversation with Vendor {VENDOR_ID}...")
response = requests.post(
    f"{API_BASE}/conversations/",
    params={"team_id": TEAM_ID},
    json={
        "vendor_id": VENDOR_ID,
        "title": "Price Negotiation Session"
    }
)

if response.status_code not in [200, 201]:
    print(f"❌ Failed to create conversation: {response.status_code}")
    print(response.text)
    exit(1)

conversation_id = response.json()["id"]
print(f"✅ Conversation created (ID: {conversation_id})")

# Chat loop
print("\n💬 Start chatting! Type 'quit' or 'exit' to stop.\n")

while True:
    user_message = input("You: ").strip()
    
    if not user_message:
        continue
    
    if user_message.lower() in ['quit', 'exit', 'stop']:
        print("\n👋 Goodbye!")
        break
    
    # Send message and get AI response
    response = requests.post(
        f"{API_BASE}/messages/{conversation_id}",
        data={"content": user_message}
    )
    
    if response.status_code in [200, 201]:
        ai_response = response.json()
        print(f"\n🤖 Vendor {VENDOR_ID}: {ai_response.get('content', 'No response')}\n")
    else:
        print(f"❌ Error: {response.status_code}")
        if response.status_code == 429:
            print("⏳ Rate limit reached. Wait a moment and try again.")
# Out:
# 🤝 Negotiation Bot - Vendor 44 Chat
# ==================================================
#
# 📝 Creating conversation with Vendor 44...
# ✅ Conversation created (ID: 140)
#
# 💬 Start chatting! Type 'quit' or 'exit' to stop.
#
#
# 🤖 Vendor 44: Ciao! Bellissimo to hear from you. How can I assist you in your journey towards the perfect espresso experience?
#
#
# 🤖 Vendor 44: Salve! What can I help you with today? Are you seeking a stunning espresso machine for your café?
#
#
# 🤖 Vendor 44: It seems we’ve encountered a bit of excitement! How may I assist you in achieving your coffee dreams today?
#
#
# 🤖 Vendor 44: I see there’s a burst of energy! If you have questions about our espresso machines, I'm here to help.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 34
#      31 print("\n💬 Start chatting! Type 'quit' or 'exit' to stop.\n")
#      33 while True:
# ---> 34     user_message = input("You: ").strip()
#      36     if not user_message:
#      37         continue
#
# File ~/Github_Projects/Start-Munich-Hack-AskLeo/backend/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# File ~/Github_Projects/Start-Munich-Hack-AskLeo/backend/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py:1441, in Kernel._input_request(self, prompt, ident, parent, password)
#    1438 except KeyboardInterrupt:
#    1439     # re-raise KeyboardInterrupt, to truncate traceback
#    1440     msg = "Interrupted by user"
# -> 1441     raise KeyboardInterrupt(msg) from None
#    1442 except Exception:
#    1443     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
